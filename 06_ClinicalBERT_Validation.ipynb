# %% [markdown]
# This is a prototype, not a real billing tool. ICD-10-CM diagnosis coding should follow official ICD-10-CM guidelines, and CPT is maintained by the AMA for reporting medical services and procedures. Real coding requires current official resources and qualified human review.

# %% [markdown]
# Clinical Note to Candidate ICD/CPT Coding Pipeline
#
# In this notebook, we will build a beginner-friendly system that takes raw clinical note text and creates a possible coded output.
#
# The workflow is:
#
# Clinical Note
# ↓
# Tokenization + Normalization
# ↓
# NER, find entities
# ↓
# Context + Time understanding
# ↓
# Classification, predict coding concepts
# ↓
# Map to ICD/CPT
# ↓
# Final coded output
#
# Important:
#
# This notebook is for learning only.
#
# It does not replace a certified medical coder.
#
# It does not produce final billable codes.
#
# It creates candidate codes that need human review.

# %% [markdown]
# What This Project Will Do
#
# We will use fake clinical notes.
#
# For each note, the system will:
#
# Clean the note
# Split the note into tokens
# Normalize abbreviations
# Find medical entities
# Find time expressions
# Classify possible coding concepts
# Map concepts to candidate ICD/CPT codes
# Validate evidence
# Print final coder-friendly output

# %%
# !pip install pandas transformers torch python-dateutil
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cpu)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (2.9.0.post0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.29.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil) (1.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %% [markdown]
# Step 1: Import Libraries
#
# We need:
#
# pandas: to store clinical notes in a table
# re: to clean text using patterns
# transformers: to load a biomedical NER model
# dateutil: to handle relative dates like “3 months ago”

# %%
import pandas as pd
import re

from transformers import pipeline
from dateutil.relativedelta import relativedelta
from datetime import datetime

# %% [markdown]
# Step 2: Create Raw Clinical Notes
#
# These notes are fake toy examples.
#
# Do not use real patient data in a practice notebook.
#
# Each note has:
#
# note_id
# note_date
# raw_note_text
#
# The note_date is important because time phrases like “today” or “3 months ago” need a reference date.

# %%
clinical_notes = [
    {
        "note_id": 1,
        "note_date": "2024-01-15",
        "raw_note_text": """
        Pt is a 58 y/o male with Type 2 Diabetes.
        Currently taking Metformin 1000mg BID.
        HbA1c today is 7.8%, previously 7.2% three months ago.
        Denies chest pain.
        Plan: continue Metformin and follow up in 3 months.
        """
    },
    {
        "note_id": 2,
        "note_date": "2024-01-20",
        "raw_note_text": """
        Patient has HTN treated with Lisinopril 20mg daily.
        BP today 145/92.
        Reports dizziness last week after standing.
        Plan: monitor BP at home and return in 2 weeks.
        """
    },
    {
        "note_id": 3,
        "note_date": "2024-01-22",
        "raw_note_text": """
        Patient presents to ED with chest pain and shortness of breath.
        EKG shows ST elevation.
        Aspirin 325mg given in ED.
        Cardiology consulted immediately.
        """
    }
]

df = pd.DataFrame(clinical_notes)

df
# Out:
#    note_id   note_date                                      raw_note_text
# 0        1  2024-01-15  \n        Pt is a 58 y/o male with Type 2 Diab...
# 1        2  2024-01-20  \n        Patient has HTN treated with Lisinop...
# 2        3  2024-01-22  \n        Patient presents to ED with chest pa...

# %% [markdown]
# Step 3: Clean the Raw Text
#
# Clinical notes are often messy.
#
# They may contain:
#
# extra line breaks
# repeated spaces
# abbreviations
# medication doses
# lab values
#
# We will clean only the spacing.
#
# We do not want to remove useful clinical details like:
#
# 1000mg
# 145/92
# HbA1c
# BID
# y/o
# EKG

# %%
def clean_text(text):
    text = re.sub(r"\s+", " ", text)
    text = text.strip()
    return text

# %%
df["clean_text"] = df["raw_note_text"].apply(clean_text)

df[["note_id", "clean_text"]]
# Out:
#    note_id                                         clean_text
# 0        1  Pt is a 58 y/o male with Type 2 Diabetes. Curr...
# 1        2  Patient has HTN treated with Lisinopril 20mg d...
# 2        3  Patient presents to ED with chest pain and sho...

# %% [markdown]
# Explanation
#
# This line:
#
# re.sub(r"\s+", " ", text)
#
# means:
#
# Find extra spaces, tabs, and line breaks.
#
# Replace them with one normal space.
#
# This line:
#
# text.strip()
#
# removes spaces from the beginning and end.

# %% [markdown]
# Step 4: Tokenization
#
# Tokenization means splitting text into smaller pieces.
#
# Example:
#
# Patient has diabetes.
#
# Tokens:
#
# Patient
# has
# diabetes
#
# We will use simple regex tokenization so beginners do not need extra NLTK setup.

# %%
def tokenize_text(text):
    tokens = re.findall(r"[A-Za-z0-9/%\.]+", text)
    return tokens

# %%
df["tokens"] = df["clean_text"].apply(tokenize_text)

df[["note_id", "tokens"]]
# Out:
#    note_id                                             tokens
# 0        1  [Pt, is, a, 58, y/o, male, with, Type, 2, Diab...
# 1        2  [Patient, has, HTN, treated, with, Lisinopril,...
# 2        3  [Patient, presents, to, ED, with, chest, pain,...

# %% [markdown]
# Step 5: Normalization
#
# Normalization means converting clinical abbreviations into clearer words.
#
# Examples:
#
# HTN → hypertension
# BP → blood pressure
# EKG → electrocardiogram
# SOB → shortness of breath
# BID → twice daily
# Pt → patient
#
# Why do we normalize?
#
# Because models and rules work better when the language is clearer.

# %%
abbreviation_map = {
    "pt": "patient",
    "htn": "hypertension",
    "bp": "blood pressure",
    "ekg": "electrocardiogram",
    "sob": "shortness of breath",
    "bid": "twice daily",
    "ed": "emergency department"
}


def normalize_text(text):
    normalized = text.lower()

    for abbreviation, full_form in abbreviation_map.items():
        pattern = r"\b" + abbreviation + r"\b"
        normalized = re.sub(pattern, full_form, normalized)

    normalized = re.sub(r"\s+", " ", normalized).strip()

    return normalized

# %%
df["normalized_text"] = df["clean_text"].apply(normalize_text)

df[["note_id", "clean_text", "normalized_text"]]
# Out:
#    note_id                                         clean_text  \
# 0        1  Pt is a 58 y/o male with Type 2 Diabetes. Curr...
# 1        2  Patient has HTN treated with Lisinopril 20mg d...
# 2        3  Patient presents to ED with chest pain and sho...
#
#                                      normalized_text
# 0  patient is a 58 y/o male with type 2 diabetes....
# 1  patient has hypertension treated with lisinopr...
# 2  patient presents to emergency department with ...

# %% [markdown]
# This dictionary:
#
# abbreviation_map
#
# stores abbreviations and their meanings.
#
# Example:
#
# "htn": "hypertension"
#
# This loop:
#
# for abbreviation, full_form in abbreviation_map.items():
#
# goes through every abbreviation and replaces it with the full meaning.
#
# The pattern:
#
# \b
#
# means word boundary.
#
# It helps replace the abbreviation only when it appears as a full word.

# %% [markdown]
# Step 6: Load Biomedical NER Model
#
# NER means Named Entity Recognition.
#
# NER finds medical words or phrases.
#
# Examples:
#
# Type 2 Diabetes
# Metformin
# HbA1c
# chest pain
# Lisinopril
# Aspirin
#
# We will use a biomedical NER model from Hugging Face.

# %%
ner_model = pipeline(
    task="token-classification",
    model="d4data/biomedical-ner-all",
    aggregation_strategy="simple"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/266M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %% [markdown]
# Step 7: Extract Entities
#
# The model output can look complicated.
#
# So we will keep only:
#
# text
# label
# confidence

# %%
def extract_entities(text):
    raw_entities = ner_model(text)

    entities = []

    for entity in raw_entities:
        entities.append({
            "text": entity["word"],
            "label": entity["entity_group"],
            "confidence": round(entity["score"], 2)
        })

    return entities

# %%
df["entities"] = df["clean_text"].apply(extract_entities)

df[["note_id", "entities"]]
# Out:
#    note_id                                           entities
# 0        1  [{'text': 'pt', 'label': 'Disease_disorder', '...
# 1        2  [{'text': 'htn', 'label': 'Medication', 'confi...
# 2        3  [{'text': 'presents', 'label': 'Clinical_event...

# %%
for i in range(len(df)):
    print("NOTE ID:", df.iloc[i]["note_id"])
    print("NOTE:", df.iloc[i]["clean_text"])
    print()
    print("ENTITIES FOUND:")

    for entity in df.iloc[i]["entities"]:
        print("Entity:", entity["text"])
        print("Label:", entity["label"])
        print("Confidence:", entity["confidence"])
        print()

    print("=" * 80)
# Out:
# NOTE ID: 1
# NOTE: Pt is a 58 y/o male with Type 2 Diabetes. Currently taking Metformin 1000mg BID. HbA1c today is 7.8%, previously 7.2% three months ago. Denies chest pain. Plan: continue Metformin and follow up in 3 months.
#
# ENTITIES FOUND:
# Entity: pt
# Label: Disease_disorder
# Confidence: 0.98
#
# Entity: 58 y / o
# Label: Lab_value
# Confidence: 1.0
#
# Entity: male
# Label: Sex
# Confidence: 0.99
#
# Entity: type 2
# Label: History
# Confidence: 0.99
#
# Entity: metform
# Label: Medication
# Confidence: 0.95
#
# Entity: 1000mg
# Label: Dosage
# Confidence: 0.78
#
# Entity: hba1c
# Label: Medication
# Confidence: 0.98
#
# Entity: 7
# Label: Lab_value
# Confidence: 0.95
#
# Entity: 7. 2 %
# Label: Lab_value
# Confidence: 0.89
#
# Entity: three months
# Label: Duration
# Confidence: 0.61
#
# Entity: chest
# Label: Biological_structure
# Confidence: 1.0
#
# Entity: metform
# Label: Medication
# Confidence: 0.92
#
# ================================================================================
# NOTE ID: 2
# NOTE: Patient has HTN treated with Lisinopril 20mg daily. BP today 145/92. Reports dizziness last week after standing. Plan: monitor BP at home and return in 2 weeks.
#
# ENTITIES FOUND:
# Entity: htn
# Label: Medication
# Confidence: 0.74
#
# Entity: li
# Label: Medication
# Confidence: 1.0
#
# Entity: ##sin
# Label: Medication
# Confidence: 1.0
#
# Entity: ##opril
# Label: Medication
# Confidence: 1.0
#
# Entity: 20mg
# Label: Dosage
# Confidence: 1.0
#
# Entity: bp
# Label: Diagnostic_procedure
# Confidence: 1.0
#
# Entity: 145
# Label: Lab_value
# Confidence: 0.98
#
# Entity: di
# Label: Sign_symptom
# Confidence: 1.0
#
# Entity: ##zziness
# Label: Sign_symptom
# Confidence: 1.0
#
# Entity: last week
# Label: Date
# Confidence: 0.99
#
# Entity: bp
# Label: Diagnostic_procedure
# Confidence: 0.99
#
# Entity: home
# Label: Nonbiological_location
# Confidence: 1.0
#
# Entity: return
# Label: Clinical_event
# Confidence: 0.99
#
# ================================================================================
# NOTE ID: 3
# NOTE: Patient presents to ED with chest pain and shortness of breath. EKG shows ST elevation. Aspirin 325mg given in ED. Cardiology consulted immediately.
#
# ENTITIES FOUND:
# Entity: presents
# Label: Clinical_event
# Confidence: 1.0
#
# Entity: chest
# Label: Biological_structure
# Confidence: 1.0
#
# Entity: pain
# Label: Sign_symptom
# Confidence: 1.0
#
# Entity: shortness of breath
# Label: Sign_symptom
# Confidence: 1.0
#
# Entity: ekg
# Label: Diagnostic_procedure
# Confidence: 1.0
#
# Entity: st
# Label: Detailed_description
# Confidence: 0.83
#
# Entity: aspirin
# Label: Medication
# Confidence: 0.86
#
# Entity: 325mg
# Label: Dosage
# Confidence: 0.99
#
# Entity: card
# Label: Diagnostic_procedure
# Confidence: 0.41
#
# ================================================================================

# %% [markdown]
# Step 8: Context + Time Understanding
#
# Now we find time expressions.
#
# Examples:
#
# today
# three months ago
# last week
# in 3 months
# in 2 weeks
# immediately
#
# Why do we need this?
#
# Because coding and clinical understanding often depend on whether something is:
#
# current
# historical
# planned
# acute
# follow-up
# Cell 26 — Code

# %%
def normalize_relative_time(time_text, note_date):
    note_datetime = datetime.strptime(note_date, "%Y-%m-%d")

    time_text_lower = time_text.lower()

    if time_text_lower == "today":
        return note_datetime.strftime("%Y-%m-%d")

    if time_text_lower in ["three months ago", "3 months ago"]:
        estimated_date = note_datetime - relativedelta(months=3)
        return estimated_date.strftime("%Y-%m-%d")

    if time_text_lower == "last week":
        estimated_date = note_datetime - relativedelta(weeks=1)
        return estimated_date.strftime("%Y-%m-%d")

    if time_text_lower == "in 3 months":
        estimated_date = note_datetime + relativedelta(months=3)
        return estimated_date.strftime("%Y-%m-%d")

    if time_text_lower == "in 2 weeks":
        estimated_date = note_datetime + relativedelta(weeks=2)
        return estimated_date.strftime("%Y-%m-%d")

    if time_text_lower == "immediately":
        return note_datetime.strftime("%Y-%m-%d") + " same day / immediate"

    return "not stated"

# %% [markdown]
# Simplified Human Version
#
# The code is basically saying:
#
# If text says "today"
#     return today's date
#
# If text says "3 months ago"
#     subtract 3 months
#
# If text says "last week"
#     subtract 1 week
#
# If text says "in 3 months"
#     add 3 months
#
# Otherwise
#     return "not stated"
# Most Important Concepts You Just Learned
# 1. Functions
# def something():
#
# Reusable tool.
#
# 2. Conditions
# if something:
#
# Decision making.
#
# 3. String methods
# .lower()
#
# Modify text.
#
# 4. Date conversion
# string → datetime → string
#
# Very common.
#
# 5. Date arithmetic
# + relativedelta()
# - relativedelta()
#
# Move through time.
#
# The REAL Thing to Understand
#
# Don’t memorize:
#
# strftime
# strptime
# relativedelta
#
# Instead understand the flow:
#
# Receive text
# ↓
# Convert date
# ↓
# Check condition
# ↓
# Calculate date
# ↓
# Return result

# %%
def extract_time_expressions(text, note_date):
    possible_times = [
        "today",
        "three months ago",
        "3 months ago",
        "last week",
        "in 3 months",
        "in 2 weeks",
        "immediately"
    ]

    time_results = []

    text_lower = text.lower()

    for time_text in possible_times:
        if time_text in text_lower:
            time_results.append({
                "time_text": time_text,
                "normalized_time": normalize_relative_time(time_text, note_date)
            })

    return time_results

# %%
df["time_expressions"] = df.apply(
    lambda row: extract_time_expressions(
        row["clean_text"],
        row["note_date"]
    ),
    axis=1
)

df[["note_id", "note_date", "time_expressions"]]
# Out:
#    note_id   note_date                                   time_expressions
# 0        1  2024-01-15  [{'time_text': 'today', 'normalized_time': '20...
# 1        2  2024-01-20  [{'time_text': 'today', 'normalized_time': '20...
# 2        3  2024-01-22  [{'time_text': 'immediately', 'normalized_time...

# %% [markdown]
# This function looks for time words.
#
# If it finds:
#
# today
#
# and the note date is:
#
# 2024-01-15
#
# then normalized_time becomes:
#
# 2024-01-15
#
# If it finds:
#
# three months ago
#
# then it subtracts 3 months from the note date.
#
# This is not perfect, but it is a good beginner version.

# %% [markdown]
# Step 9: Classification, Predict Coding Concepts
#
# Before mapping to ICD/CPT, we first classify the note into coding concepts.
#
# This means:
#
# The note mentions diabetes → predict concept type_2_diabetes
# The note mentions hypertension → predict concept hypertension
# The note mentions chest pain → predict concept chest_pain
# The note mentions EKG → predict concept ekg_performed_or_reviewed
#
# Important:
#
# This is a simple rule-based classifier for learning.
#
# In real systems, this could be replaced by:
#
# a fine-tuned ClinicalBERT classifier
# a Clinical LLM
# a professional coding engine
# human coder review

# %%
def classify_coding_concepts(text):
    text_lower = text.lower()

    concepts = []

    if "type 2 diabetes" in text_lower or "diabetes" in text_lower:
        concepts.append({
            "concept": "type_2_diabetes",
            "category": "diagnosis",
            "evidence": "Type 2 Diabetes" if "type 2 diabetes" in text_lower else "diabetes"
        })

    if "hypertension" in text_lower:
        concepts.append({
            "concept": "hypertension",
            "category": "diagnosis",
            "evidence": "hypertension"
        })

    if "chest pain" in text_lower and "denies chest pain" not in text_lower:
        concepts.append({
            "concept": "chest_pain",
            "category": "diagnosis_or_symptom",
            "evidence": "chest pain"
        })

    if "shortness of breath" in text_lower:
        concepts.append({
            "concept": "shortness_of_breath",
            "category": "diagnosis_or_symptom",
            "evidence": "shortness of breath"
        })

    if "st elevation" in text_lower or "electrocardiogram shows" in text_lower:
        concepts.append({
            "concept": "abnormal_ekg",
            "category": "diagnosis_or_finding",
            "evidence": "ST elevation" if "st elevation" in text_lower else "electrocardiogram shows"
        })

    if "electrocardiogram" in text_lower:
        concepts.append({
            "concept": "ekg_performed_or_reviewed",
            "category": "procedure_or_test",
            "evidence": "EKG" if "ekg" in text_lower else "electrocardiogram"
        })

    if "follow up" in text_lower or "return in" in text_lower:
        concepts.append({
            "concept": "follow_up_planned",
            "category": "care_plan",
            "evidence": "follow up" if "follow up" in text_lower else "return in"
        })

    if "aspirin" in text_lower and "given" in text_lower:
        concepts.append({
            "concept": "medication_given",
            "category": "treatment",
            "evidence": "Aspirin 325mg given" if "aspirin 325mg given" in text_lower else "aspirin given"
        })

    return concepts

# %%
df["coding_concepts"] = df["normalized_text"].apply(classify_coding_concepts)

df[["note_id", "coding_concepts"]]
# Out:
#    note_id                                    coding_concepts
# 0        1  [{'concept': 'type_2_diabetes', 'category': 'd...
# 1        2  [{'concept': 'hypertension', 'category': 'diag...
# 2        3  [{'concept': 'chest_pain', 'category': 'diagno...

# %% [markdown]
# This is the basic pattern:
#
# if "diabetes" in note:
# predict diabetes concept
#
# The classifier does not directly assign ICD/CPT codes yet.
#
# It first predicts a concept.
#
# Then the next step maps the concept to candidate codes.
#
# This keeps the workflow easier to understand:
#
# Text
# ↓
# Concept
# ↓
# Code

# %% [markdown]
# Step 10: Map Concepts to ICD/CPT
#
# Now we create a small educational mapping.
#
# Important:
#
# This is a tiny toy mapping.
#
# It is not a complete coding system.
#
# Real coding must use official, current ICD/CPT resources and human review.
#
# ICD-10-CM is used for diagnosis coding guidance in the United States, while CPT codes describe medical services and procedures performed by physicians and other qualified health care professionals.

# %%
concept_to_code_map = {
    "type_2_diabetes": [
        {
            "code_system": "ICD-10-CM",
            "code": "E11.9",
            "description": "Type 2 diabetes mellitus without complications",
            "coding_note": "Educational candidate only. Confirm complications and documentation."
        }
    ],
    "hypertension": [
        {
            "code_system": "ICD-10-CM",
            "code": "I10",
            "description": "Essential hypertension",
            "coding_note": "Educational candidate only. Confirm diagnosis documentation."
        }
    ],
    "chest_pain": [
        {
            "code_system": "ICD-10-CM",
            "code": "R07.9",
            "description": "Chest pain, unspecified",
            "coding_note": "Educational candidate only. Final coding depends on final diagnosis."
        }
    ],
    "shortness_of_breath": [
        {
            "code_system": "ICD-10-CM",
            "code": "R06.02",
            "description": "Shortness of breath",
            "coding_note": "Educational candidate only."
        }
    ],
    "abnormal_ekg": [
        {
            "code_system": "ICD-10-CM",
            "code": "R94.31",
            "description": "Abnormal electrocardiogram",
            "coding_note": "Educational candidate only. Confirm final interpretation."
        }
    ],
    "ekg_performed_or_reviewed": [
        {
            "code_system": "CPT",
            "code": "EKG CPT candidate",
            "description": "Electrocardiogram service candidate",
            "coding_note": "Exact CPT depends on tracing, interpretation, report, setting, and payer rules."
        }
    ],
    "follow_up_planned": [
        {
            "code_system": "Workflow",
            "code": "FOLLOW_UP",
            "description": "Follow-up planned",
            "coding_note": "Workflow action, not a billing code."
        }
    ],
    "medication_given": [
        {
            "code_system": "Workflow",
            "code": "MED_ADMIN_REVIEW",
            "description": "Medication administration mentioned",
            "coding_note": "Workflow flag. Procedure coding depends on setting and documentation."
        }
    ]
}

# %% [markdown]
# concept_to_code_map
# │
# ├── "type_2_diabetes"
# │        ↓
# │      List
# │        ↓
# │      Dictionary
# │         ├── code_system
# │         ├── code
# │         ├── description
# │         └── coding_note
# │
# ├── "hypertension"
# │
# └── "chest_pain"

# %% [markdown]
# Because one concept may eventually have:
#
# multiple ICD codes
# multiple CPT codes
# multiple workflows
#
# So list allows MANY coding options.
#
# PART 3 — Inner Dictionary
#
# This part:
#
# {
#     "code_system": "ICD-10-CM",
#     "code": "E11.9",
#     "description": "...",
#     "coding_note": "..."
# }
#
# stores structured metadata.
#
# Meaning of Each Field
# code_system
# "ICD-10-CM"
#
# Which coding standard is being used.
#
# code
# "E11.9"

# %% [markdown]
# Why CPT Is Different
#
# ICD codes usually describe diagnoses, symptoms, or findings.
#
# CPT codes usually describe services and procedures.
#
# For example:
#
# diagnosis: diabetes
# symptom: chest pain
# procedure/service: EKG
#
# CPT coding often needs more documentation than a short note gives.
#
# For example, an EKG code may depend on:
#
# whether tracing was performed
# whether interpretation was performed
# whether a formal report exists
# care setting
# payer rules

# %%
def map_concepts_to_codes(concepts):
    code_candidates = []

    for concept in concepts:
        concept_name = concept["concept"]

        if concept_name in concept_to_code_map:
            mapped_codes = concept_to_code_map[concept_name]

            for mapped_code in mapped_codes:
                code_candidate = {
                    "concept": concept_name,
                    "category": concept["category"],
                    "evidence": concept["evidence"],
                    "code_system": mapped_code["code_system"],
                    "code": mapped_code["code"],
                    "description": mapped_code["description"],
                    "coding_note": mapped_code["coding_note"],
                    "needs_coder_review": True
                }

                code_candidates.append(code_candidate)

    return code_candidates

# %%
df["code_candidates"] = df["coding_concepts"].apply(map_concepts_to_codes)

df[["note_id", "code_candidates"]]
# Out:
#    note_id                                    code_candidates
# 0        1  [{'concept': 'type_2_diabetes', 'category': 'd...
# 1        2  [{'concept': 'hypertension', 'category': 'diag...
# 2        3  [{'concept': 'chest_pain', 'category': 'diagno...

# %% [markdown]
# Step 11: Validate Evidence
#
# Now we check whether the evidence appears in the note.
#
# If the evidence is found in the note:
#
# evidence_found_in_note = True
#
# If not:
#
# evidence_found_in_note = False
# needs_coder_review = True
#
# This helps reduce hallucination or unsupported coding suggestions.

# %%
def validate_code_evidence(note_text, code_candidates):
    note_lower = note_text.lower()

    validated_codes = []

    for candidate in code_candidates:
        evidence_lower = candidate["evidence"].lower()

        if evidence_lower in note_lower:
            candidate["evidence_found_in_note"] = True
            candidate["validation_reason"] = "Evidence found in note."
        else:
            candidate["evidence_found_in_note"] = False
            candidate["validation_reason"] = "Evidence not found exactly in note. Human review required."
            candidate["needs_coder_review"] = True

        validated_codes.append(candidate)

    return validated_codes

# %%
df["validated_codes"] = df.apply(
    lambda row: validate_code_evidence(
        row["clean_text"],
        row["code_candidates"]
    ),
    axis=1
)

df[["note_id", "validated_codes"]]
# Out:
#    note_id                                    validated_codes
# 0        1  [{'concept': 'type_2_diabetes', 'category': 'd...
# 1        2  [{'concept': 'hypertension', 'category': 'diag...
# 2        3  [{'concept': 'chest_pain', 'category': 'diagno...

# %% [markdown]
# Step 12: Final Coded Output
#
# Now we combine everything:
#
# clean note
# tokens
# normalized text
# entities
# time expressions
# predicted concepts
# candidate codes
# validation result
#
# This is the final output for a coder or doctor to review.

# %%
def print_final_coded_output(row):
    print("NOTE ID:", row["note_id"])
    print("NOTE DATE:", row["note_date"])
    print()

    print("CLEAN NOTE:")
    print(row["clean_text"])
    print()

    print("TOKENS:")
    print(row["tokens"])
    print()

    print("NORMALIZED TEXT:")
    print(row["normalized_text"])
    print()

    print("MEDICAL ENTITIES FOUND:")
    for entity in row["entities"]:
        print("-", entity["text"], "|", entity["label"], "| confidence:", entity["confidence"])
    print()

    print("TIME EXPRESSIONS:")
    for time_item in row["time_expressions"]:
        print("-", time_item["time_text"], "→", time_item["normalized_time"])
    print()

    print("PREDICTED CODING CONCEPTS:")
    for concept in row["coding_concepts"]:
        print("-", concept["concept"])
        print("  Category:", concept["category"])
        print("  Evidence:", concept["evidence"])
    print()

    print("FINAL CODE CANDIDATES:")
    for code in row["validated_codes"]:
        print()
        print("Concept:", code["concept"])
        print("Code system:", code["code_system"])
        print("Candidate code:", code["code"])
        print("Description:", code["description"])
        print("Evidence:", code["evidence"])
        print("Evidence found in note:", code["evidence_found_in_note"])
        print("Needs coder review:", code["needs_coder_review"])
        print("Validation:", code["validation_reason"])
        print("Coding note:", code["coding_note"])

    print()
    print("=" * 100)

# %%
for i in range(len(df)):
    print_final_coded_output(df.iloc[i])
# Out:
# NOTE ID: 1
# NOTE DATE: 2024-01-15
#
# CLEAN NOTE:
# Pt is a 58 y/o male with Type 2 Diabetes. Currently taking Metformin 1000mg BID. HbA1c today is 7.8%, previously 7.2% three months ago. Denies chest pain. Plan: continue Metformin and follow up in 3 months.
#
# TOKENS:
# ['Pt', 'is', 'a', '58', 'y/o', 'male', 'with', 'Type', '2', 'Diabetes.', 'Currently', 'taking', 'Metformin', '1000mg', 'BID.', 'HbA1c', 'today', 'is', '7.8%', 'previously', '7.2%', 'three', 'months', 'ago.', 'Denies', 'chest', 'pain.', 'Plan', 'continue', 'Metformin', 'and', 'follow', 'up', 'in', '3', 'months.']
#
# NORMALIZED TEXT:
# patient is a 58 y/o male with type 2 diabetes. currently taking metformin 1000mg twice daily. hba1c today is 7.8%, previously 7.2% three months ago. denies chest pain. plan: continue metformin and follow up in 3 months.
#
# MEDICAL ENTITIES FOUND:
# - pt | Disease_disorder | confidence: 0.98
# - 58 y / o | Lab_value | confidence: 1.0
# - male | Sex | confidence: 0.99
# - type 2 | History | confidence: 0.99
# - metform | Medication | confidence: 0.95
# - 1000mg | Dosage | confidence: 0.78
# - hba1c | Medication | confidence: 0.98
# - 7 | Lab_value | confidence: 0.95
# - 7. 2 % | Lab_value | confidence: 0.89
# - three months | Duration | confidence: 0.61
# - chest | Biological_structure | confidence: 1.0
# - metform | Medication | confidence: 0.92
#
# TIME EXPRESSIONS:
# - today → 2024-01-15
# - three months ago → 2023-10-15
# - in 3 months → 2024-04-15
#
# PREDICTED CODING CONCEPTS:
# - type_2_diabetes
#   Category: diagnosis
#   Evidence: Type 2 Diabetes
# - follow_up_planned
#   Category: care_plan
#   Evidence: follow up
#
# FINAL CODE CANDIDATES:
#
# Concept: type_2_diabetes
# Code system: ICD-10-CM
# Candidate code: E11.9
# Description: Type 2 diabetes mellitus without complications
# Evidence: Type 2 Diabetes
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Educational candidate only. Confirm complications and documentation.
#
# Concept: follow_up_planned
# Code system: Workflow
# Candidate code: FOLLOW_UP
# Description: Follow-up planned
# Evidence: follow up
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Workflow action, not a billing code.
#
# ====================================================================================================
# NOTE ID: 2
# NOTE DATE: 2024-01-20
#
# CLEAN NOTE:
# Patient has HTN treated with Lisinopril 20mg daily. BP today 145/92. Reports dizziness last week after standing. Plan: monitor BP at home and return in 2 weeks.
#
# TOKENS:
# ['Patient', 'has', 'HTN', 'treated', 'with', 'Lisinopril', '20mg', 'daily.', 'BP', 'today', '145/92.', 'Reports', 'dizziness', 'last', 'week', 'after', 'standing.', 'Plan', 'monitor', 'BP', 'at', 'home', 'and', 'return', 'in', '2', 'weeks.']
#
# NORMALIZED TEXT:
# patient has hypertension treated with lisinopril 20mg daily. blood pressure today 145/92. reports dizziness last week after standing. plan: monitor blood pressure at home and return in 2 weeks.
#
# MEDICAL ENTITIES FOUND:
# - htn | Medication | confidence: 0.74
# - li | Medication | confidence: 1.0
# - ##sin | Medication | confidence: 1.0
# - ##opril | Medication | confidence: 1.0
# - 20mg | Dosage | confidence: 1.0
# - bp | Diagnostic_procedure | confidence: 1.0
# - 145 | Lab_value | confidence: 0.98
# - di | Sign_symptom | confidence: 1.0
# - ##zziness | Sign_symptom | confidence: 1.0
# - last week | Date | confidence: 0.99
# - bp | Diagnostic_procedure | confidence: 0.99
# - home | Nonbiological_location | confidence: 1.0
# - return | Clinical_event | confidence: 0.99
#
# TIME EXPRESSIONS:
# - today → 2024-01-20
# - last week → 2024-01-13
# - in 2 weeks → 2024-02-03
#
# PREDICTED CODING CONCEPTS:
# - hypertension
#   Category: diagnosis
#   Evidence: hypertension
# - follow_up_planned
#   Category: care_plan
#   Evidence: return in
#
# FINAL CODE CANDIDATES:
#
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# Evidence: hypertension
# Evidence found in note: False
# Needs coder review: True
# Validation: Evidence not found exactly in note. Human review required.
# Coding note: Educational candidate only. Confirm diagnosis documentation.
#
# Concept: follow_up_planned
# Code system: Workflow
# Candidate code: FOLLOW_UP
# Description: Follow-up planned
# Evidence: return in
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Workflow action, not a billing code.
#
# ====================================================================================================
# NOTE ID: 3
# NOTE DATE: 2024-01-22
#
# CLEAN NOTE:
# Patient presents to ED with chest pain and shortness of breath. EKG shows ST elevation. Aspirin 325mg given in ED. Cardiology consulted immediately.
#
# TOKENS:
# ['Patient', 'presents', 'to', 'ED', 'with', 'chest', 'pain', 'and', 'shortness', 'of', 'breath.', 'EKG', 'shows', 'ST', 'elevation.', 'Aspirin', '325mg', 'given', 'in', 'ED.', 'Cardiology', 'consulted', 'immediately.']
#
# NORMALIZED TEXT:
# patient presents to emergency department with chest pain and shortness of breath. electrocardiogram shows st elevation. aspirin 325mg given in emergency department. cardiology consulted immediately.
#
# MEDICAL ENTITIES FOUND:
# - presents | Clinical_event | confidence: 1.0
# - chest | Biological_structure | confidence: 1.0
# - pain | Sign_symptom | confidence: 1.0
# - shortness of breath | Sign_symptom | confidence: 1.0
# - ekg | Diagnostic_procedure | confidence: 1.0
# - st | Detailed_description | confidence: 0.83
# - aspirin | Medication | confidence: 0.86
# - 325mg | Dosage | confidence: 0.99
# - card | Diagnostic_procedure | confidence: 0.41
#
# TIME EXPRESSIONS:
# - immediately → 2024-01-22 same day / immediate
#
# PREDICTED CODING CONCEPTS:
# - chest_pain
#   Category: diagnosis_or_symptom
#   Evidence: chest pain
# - shortness_of_breath
#   Category: diagnosis_or_symptom
#   Evidence: shortness of breath
# - abnormal_ekg
#   Category: diagnosis_or_finding
#   Evidence: ST elevation
# - ekg_performed_or_reviewed
#   Category: procedure_or_test
#   Evidence: electrocardiogram
# - medication_given
#   Category: treatment
#   Evidence: Aspirin 325mg given
#
# FINAL CODE CANDIDATES:
#
# Concept: chest_pain
# Code system: ICD-10-CM
# Candidate code: R07.9
# Description: Chest pain, unspecified
# Evidence: chest pain
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Educational candidate only. Final coding depends on final diagnosis.
#
# Concept: shortness_of_breath
# Code system: ICD-10-CM
# Candidate code: R06.02
# Description: Shortness of breath
# Evidence: shortness of breath
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Educational candidate only.
#
# Concept: abnormal_ekg
# Code system: ICD-10-CM
# Candidate code: R94.31
# Description: Abnormal electrocardiogram
# Evidence: ST elevation
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Educational candidate only. Confirm final interpretation.
#
# Concept: ekg_performed_or_reviewed
# Code system: CPT
# Candidate code: EKG CPT candidate
# Description: Electrocardiogram service candidate
# Evidence: electrocardiogram
# Evidence found in note: False
# Needs coder review: True
# Validation: Evidence not found exactly in note. Human review required.
# Coding note: Exact CPT depends on tracing, interpretation, report, setting, and payer rules.
#
# Concept: medication_given
# Code system: Workflow
# Candidate code: MED_ADMIN_REVIEW
# Description: Medication administration mentioned
# Evidence: Aspirin 325mg given
# Evidence found in note: True
# Needs coder review: True
# Validation: Evidence found in note.
# Coding note: Workflow flag. Procedure coding depends on setting and documentation.
#
# ====================================================================================================

# %% [markdown]
# Step 13: Create a Compact Final Table
#
# Sometimes you want the output in a table.
#
# We will create one row per candidate code.

# %%
final_rows = []

for i in range(len(df)):
    row = df.iloc[i]

    for code in row["validated_codes"]:
        final_rows.append({
            "note_id": row["note_id"],
            "note_date": row["note_date"],
            "concept": code["concept"],
            "code_system": code["code_system"],
            "candidate_code": code["code"],
            "description": code["description"],
            "evidence": code["evidence"],
            "evidence_found_in_note": code["evidence_found_in_note"],
            "needs_coder_review": code["needs_coder_review"],
            "coding_note": code["coding_note"]
        })

final_code_table = pd.DataFrame(final_rows)

final_code_table
# Out:
#    note_id   note_date                    concept code_system  \
# 0        1  2024-01-15            type_2_diabetes   ICD-10-CM
# 1        1  2024-01-15          follow_up_planned    Workflow
# 2        2  2024-01-20               hypertension   ICD-10-CM
# 3        2  2024-01-20          follow_up_planned    Workflow
# 4        3  2024-01-22                 chest_pain   ICD-10-CM
# 5        3  2024-01-22        shortness_of_breath   ICD-10-CM
# 6        3  2024-01-22               abnormal_ekg   ICD-10-CM
# 7        3  2024-01-22  ekg_performed_or_reviewed         CPT
# 8        3  2024-01-22           medication_given    Workflow
#
#       candidate_code                                     description  \
# 0              E11.9  Type 2 diabetes mellitus without complications
# 1          FOLLOW_UP                               Follow-up planned
# 2                I10                          Essential hypertension
# 3          FOLLOW_UP                               Follow-up planned
# 4              R07.9                         Chest pain, unspecified
# 5             R06.02                             Shortness of breath
# 6             R94.31                      Abnormal electrocardiogram
# 7  EKG CPT candidate             Electrocardiogram service candidate
# 8   MED_ADMIN_REVIEW             Medication administration mentioned
#
#               evidence  evidence_found_in_note  needs_coder_review  \
# 0      Type 2 Diabetes                    True                True
# 1            follow up                    True                True
# 2         hypertension                   False                True
# 3            return in                    True                True
# 4           chest pain                    True                True
# 5  shortness of breath                    True                True
# 6         ST elevation                    True                True
# 7    electrocardiogram                   False                True
# 8  Aspirin 325mg given                    True                True
#
#                                          coding_note
# 0  Educational candidate only. Confirm complicati...
# 1               Workflow action, not a billing code.
# 2  Educational candidate only. Confirm diagnosis ...
# 3               Workflow action, not a billing code.
# 4  Educational candidate only. Final coding depen...
# 5                        Educational candidate only.
# 6  Educational candidate only. Confirm final inte...
# 7  Exact CPT depends on tracing, interpretation, ...
# 8  Workflow flag. Procedure coding depends on set...

# %% [markdown]
# What the Final Table Means
#
# Each row is one possible coding suggestion.
#
# Columns:
#
# note_id
# Which note the code came from.
#
# concept
# The clinical concept predicted by the classifier.
#
# code_system
# ICD-10-CM, CPT, or Workflow.
#
# candidate_code
# The possible code or workflow flag.
#
# description
# Plain-English meaning.
#
# evidence
# Text that supports the code.
#
# evidence_found_in_note
# Whether the evidence was found in the note.
#
# needs_coder_review
# Always True in this prototype because coding needs human review.
#
# coding_note
# Warning or explanation for coders.

# %% [markdown]
# Full Pipeline Function
#
# Now we create one function that runs the whole workflow on a new clinical note.
#
# This is useful because later you can give it any new note.

# %%
def clinical_note_to_candidate_codes(raw_note_text, note_date):
    clean = clean_text(raw_note_text)
    tokens = tokenize_text(clean)
    normalized = normalize_text(clean)
    entities = extract_entities(clean)
    times = extract_time_expressions(clean, note_date)
    concepts = classify_coding_concepts(normalized)
    code_candidates = map_concepts_to_codes(concepts)
    validated_codes = validate_code_evidence(clean, code_candidates)

    result = {
        "note_date": note_date,
        "clean_text": clean,
        "tokens": tokens,
        "normalized_text": normalized,
        "entities": entities,
        "time_expressions": times,
        "coding_concepts": concepts,
        "validated_codes": validated_codes
    }

    return result

# %%
new_note = """
Pt with Type 2 Diabetes on Metformin.
HbA1c today 8.1%.
No chest pain.
Return in 2 weeks.
"""

new_result = clinical_note_to_candidate_codes(
    raw_note_text=new_note,
    note_date="2024-02-01"
)

new_result
# Out:
# {'note_date': '2024-02-01',
#  'clean_text': 'Pt with Type 2 Diabetes on Metformin. HbA1c today 8.1%. No chest pain. Return in 2 weeks.',
#  'tokens': ['Pt',
#   'with',
#   'Type',
#   '2',
#   'Diabetes',
#   'on',
#   'Metformin.',
#   'HbA1c',
#   'today',
#   '8.1%.',
#   'No',
#   'chest',
#   'pain.',
#   'Return',
#   'in',
#   '2',
#   'weeks.'],
#  'normalized_text': 'patient with type 2 diabetes on metformin. hba1c today 8.1%. no chest pain. return in 2 weeks.',
#  'entities': [{'text': 'pt',
#    'label': 'Diagnostic_procedure',
#    'confidence': np.float32(0.97)},
#   {'text': 'type 2', 'label': 'History', 'confidence': np.float32(0.71)},
#   {'text': 'diabetes',
#    'label': 'Disease_disorder',
#    'confidence': np.float32(0.73)},
#   {'text': 'met', 'label': 'Medication', 'confidence': np.float32(1.0)},
#   {'text': '##form', 'label': 'Medication', 'confidence': np.float32(0.98)},
#   {'text': 'h',
#    'label': 'Diagnostic_procedure',
#    'confidence': np.float32(0.59)},
#   {'text': '##ba1c',
#    'label': 'Diagnostic_procedure',
#    'confidence': np.float32(0.56)},
#   {'text': '8', 'label': 'Lab_value', 'confidence': np.float32(1.0)},
#   {'text': '1', 'label': 'Lab_value', 'confidence': np.float32(0.61)},
#   {'text': 'chest',
#    'label': 'Biological_structure',
#    'confidence': np.float32(1.0)},
#   {'text': 'return',
#    'label': 'Clinical_event',
#    'confidence': np.float32(0.57)}],
#  'time_expressions': [{'time_text': 'today', 'normalized_time': '2024-02-01'},
#   {'time_text': 'in 2 weeks', 'normalized_time': '2024-02-15'}],
#  'coding_concepts': [{'concept': 'type_2_diabetes',
#    'category': 'diagnosis',
#    'evidence': 'Type 2 Diabetes'},
#   {'concept': 'chest_pain',
#    'category': 'diagnosis_or_symptom',
#    'evidence': 'chest pain'},
#   {'concept': 'follow_up_planned',
#    'category': 'care_plan',
#    'evidence': 'return in'}],
#  'validated_codes': [{'concept': 'type_2_diabetes',
#    'category': 'diagnosis',
#    'evidence': 'Type 2 Diabetes',
#    'code_system': 'ICD-10-CM',
#    'code': 'E11.9',
#    'description': 'Type 2 diabetes mellitus without complications',
#    'coding_note': 'Educational candidate only. Confirm complications and documentation.',
#    'needs_coder_review': True,
#    'evidence_found_in_note': True,
#    'validation_reason': 'Evidence found in note.'},
#   {'concept': 'chest_pain',
#    'category': 'diagnosis_or_symptom',
#    'evidence': 'chest pain',
#    'code_system': 'ICD-10-CM',
#    'code': 'R07.9',
#    'description': 'Chest pain, unspecified',
#    'coding_note': 'Educational candidate only. Final coding depends on final diagnosis.',
#    'needs_coder_review': True,
#    'evidence_found_in_note': True,
#    'validation_reason': 'Evidence found in note.'},
#   {'concept': 'follow_up_planned',
#    'category': 'care_plan',
#    'evidence': 'return in',
#    'code_system': 'Workflow',
#    'code': 'FOLLOW_UP',
#    'description': 'Follow-up planned',
#    'coding_note': 'Workflow action, not a billing code.',
#    'needs_coder_review': True,
#    'evidence_found_in_note': True,
#    'validation_reason': 'Evidence found in note.'}]}

# %% [markdown]
# This function follows the full workflow:
#
# raw note
# ↓
# clean text
# ↓
# tokenize
# ↓
# normalize
# ↓
# extract entities
# ↓
# find time expressions
# ↓
# classify coding concepts
# ↓
# map concepts to codes
# ↓
# validate evidence
#
# This is the pattern you should remember.

# %% [markdown]
# Avobe all of this Code related to Rule based mapping of Candidate Code from Raw clinical Note . In Down we will use ClinicalBERT Mapping as is trained with Clinical adata that good for Context understanding

# %% [markdown]
# Add ClinicalBERT to the Coding Pipeline for validate
#
# Now we add ClinicalBERT.
#
# ClinicalBERT helps the computer understand clinical language.
#
# In this beginner version, we will use ClinicalBERT to create embeddings.
#
# An embedding is a list of numbers that represents the meaning of text.
#
# Example:
#
# Clinical note
# ↓
# ClinicalBERT
# ↓
# meaning vector
#
# Then we compare:
#
# note meaning vector
# with
# code description meaning vector
#
# If they are similar, the system suggests that code as a candidate.
#
# Important:
#
# This is not final medical coding.
#
# This is a beginner prototype to show how transformer models can help predict candidate codes.

# %% [markdown]
# Cell 38B — Markdown
# Why Add ClinicalBERT?
#
# Different doctors write differently.
#
# Example:
#
# Doctor 1 writes:
#
# Patient has hypertension.
#
# Doctor 2 writes:
#
# Patient has HTN.
#
# Doctor 3 writes:
#
# Elevated blood pressure, on Lisinopril.
#
# These may all relate to similar coding concepts.
#
# ClinicalBERT helps by understanding clinical language patterns better than simple keyword rules.
#
# Simple rule approach:
#
# Look for exact words.
#
# ClinicalBERT approach:
#
# Compare meaning.

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

# %% [markdown]
# Load ClinicalBERT
#
# We will use Bio+ClinicalBERT.
#
# This model is trained for clinical language.
#
# The first time this runs, it may take time to download.

# %%
clinicalbert_model_name = "emilyalsentzer/Bio_ClinicalBERT"

clinicalbert_tokenizer = AutoTokenizer.from_pretrained(clinicalbert_model_name)
clinicalbert_model = AutoModel.from_pretrained(clinicalbert_model_name)
# Out:
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: emilyalsentzer/Bio_ClinicalBERT
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# Create a ClinicalBERT Embedding Function
#
# This function will:
#
# Take text
# Send it to ClinicalBERT
# Return a vector of numbers
#
# The vector represents the meaning of the text.

# %%
def get_clinicalbert_embedding(text):
    inputs = clinicalbert_tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        padding=True,
        max_length=512
    )

    with torch.no_grad():
        outputs = clinicalbert_model(**inputs)

    # Use the CLS token as the text representation
    cls_embedding = outputs.last_hidden_state[:, 0, :]

    # Convert tensor to numpy array
    embedding = cls_embedding.squeeze().numpy()

    return embedding

# %% [markdown]
# This function changes text into numbers.
#
# Example:
#
# "Patient has Type 2 Diabetes"
#
# becomes something like:
#
# [0.12, -0.44, 0.78, ...]
#
# There are many numbers, so we do not read them manually.
#
# The computer uses these numbers to compare meanings.

# %%
sample_embedding = get_clinicalbert_embedding("Patient has Type 2 Diabetes and takes Metformin.")

print("Embedding created.")
print("Embedding length:", len(sample_embedding))
# Out:
# Embedding created.
# Embedding length: 768

# %% [markdown]
# Create Code Descriptions for ClinicalBERT Matching
#
# Now we create a small toy vocabulary mapping.
#
# Each code has:
#
# code system
# code
# description
# concept text
#
# ClinicalBERT will compare the clinical note to these descriptions.
#
# Important:
#
# This is a tiny educational vocabulary.
#
# Real coding requires official code sets and coder review.

# %%
clinical_code_vocabulary = [
    {
        "concept": "type_2_diabetes",
        "code_system": "ICD-10-CM",
        "code": "E11.9",
        "description": "Type 2 diabetes mellitus without complications",
        "snomed_ct_candidate": "Type 2 diabetes mellitus"
    },
    {
        "concept": "hypertension",
        "code_system": "ICD-10-CM",
        "code": "I10",
        "description": "Essential hypertension",
        "snomed_ct_candidate": "Essential hypertension"
    },
    {
        "concept": "chest_pain",
        "code_system": "ICD-10-CM",
        "code": "R07.9",
        "description": "Chest pain, unspecified",
        "snomed_ct_candidate": "Chest pain"
    },
    {
        "concept": "shortness_of_breath",
        "code_system": "ICD-10-CM",
        "code": "R06.02",
        "description": "Shortness of breath",
        "snomed_ct_candidate": "Shortness of breath"
    },
    {
        "concept": "abnormal_ekg",
        "code_system": "ICD-10-CM",
        "code": "R94.31",
        "description": "Abnormal electrocardiogram",
        "snomed_ct_candidate": "Abnormal electrocardiogram"
    },
    {
        "concept": "ekg_service",
        "code_system": "CPT",
        "code": "CPT candidate for electrocardiogram",
        "description": "Electrocardiogram service or interpretation candidate",
        "snomed_ct_candidate": "Electrocardiogram procedure"
    }
]

# %% [markdown]
# Create Embeddings for Code Descriptions
#
# Now we convert every code description into a ClinicalBERT vector.
#
# That lets us compare:
#
# clinical note vector
# with
# code description vector

# %%
for code_item in clinical_code_vocabulary:
    text_for_embedding = code_item["description"] + " " + code_item["snomed_ct_candidate"]
    code_item["embedding"] = get_clinicalbert_embedding(text_for_embedding)

print("Code description embeddings created.")
# Out:
# Code description embeddings created.

# %% [markdown]
# Similarity Function
#
# Now we need a way to compare two vectors.
#
# We will use cosine similarity.
#
# Beginner meaning:
#
# Cosine similarity tells us how similar two meanings are.
#
# Higher score means more similar.
#
# Possible range:
#
# close to 1 means very similar
# close to 0 means not very similar
# negative means very different

# %%
def cosine_similarity(vector_a, vector_b):
    vector_a = np.array(vector_a)
    vector_b = np.array(vector_b)

    dot_product = np.dot(vector_a, vector_b)
    norm_a = np.linalg.norm(vector_a)
    norm_b = np.linalg.norm(vector_b)

    similarity = dot_product / (norm_a * norm_b)

    return similarity

# %% [markdown]
# Predict Candidate Codes with ClinicalBERT
#
# Now we create a function that:
#
# Takes a clinical note
# Creates a ClinicalBERT embedding for the note
# Compares the note embedding to each code embedding
# Returns the most similar candidate codes
#
# This gives us a confidence-like similarity score

# %%
def predict_codes_with_clinicalbert(note_text, top_n=3):
    note_embedding = get_clinicalbert_embedding(note_text)

    predictions = []

    for code_item in clinical_code_vocabulary:
        similarity_score = cosine_similarity(
            note_embedding,
            code_item["embedding"]
        )

        predictions.append({
            "concept": code_item["concept"],
            "code_system": code_item["code_system"],
            "code": code_item["code"],
            "description": code_item["description"],
            "snomed_ct_candidate": code_item["snomed_ct_candidate"],
            "clinicalbert_similarity": round(float(similarity_score), 3)
        })

    predictions = sorted(
        predictions,
        key=lambda x: x["clinicalbert_similarity"],
        reverse=True
    )

    return predictions[:top_n]

# %%
test_predictions = predict_codes_with_clinicalbert(
    "Patient has Type 2 Diabetes and takes Metformin.",
    top_n=3
)

test_predictions
# Out:
# [{'concept': 'hypertension',
#   'code_system': 'ICD-10-CM',
#   'code': 'I10',
#   'description': 'Essential hypertension',
#   'snomed_ct_candidate': 'Essential hypertension',
#   'clinicalbert_similarity': 0.841},
#  {'concept': 'type_2_diabetes',
#   'code_system': 'ICD-10-CM',
#   'code': 'E11.9',
#   'description': 'Type 2 diabetes mellitus without complications',
#   'snomed_ct_candidate': 'Type 2 diabetes mellitus',
#   'clinicalbert_similarity': 0.84},
#  {'concept': 'ekg_service',
#   'code_system': 'CPT',
#   'code': 'CPT candidate for electrocardiogram',
#   'description': 'Electrocardiogram service or interpretation candidate',
#   'snomed_ct_candidate': 'Electrocardiogram procedure',
#   'clinicalbert_similarity': 0.733}]

# %% [markdown]
# This function is like asking:
#
# Which code description is closest in meaning to this note?
#
# Example:
#
# Note:
#
# Patient has Type 2 Diabetes and takes Metformin.
#
# The closest code description should hopefully include:
#
# Type 2 diabetes mellitus
#
# But remember:
#
# This is only a candidate prediction.
#
# It is not final billing code assignment.

# %% [markdown]
# Add Confidence and Human Review Logic
#
# Now we add the idea:
#
# High confidence → maybe easier for coder to approve
# Low confidence → human review needed
#
# This is like spell-check:
#
# Some corrections are obvious.
#
# Some need a human decision.
#
# For this notebook, we use simple thresholds:
#
# similarity >= 0.80 → high confidence
# similarity >= 0.65 → medium confidence
# similarity < 0.65 → low confidence
#
# These thresholds are just for learning.
#
# In a real system, thresholds must be tested and validated.

# %%
def add_confidence_and_review(predictions):
    reviewed_predictions = []

    for prediction in predictions:
        score = prediction["clinicalbert_similarity"]

        if score >= 0.80:
            confidence_level = "high"
            review_decision = "candidate_auto_approve_for_demo"
        elif score >= 0.65:
            confidence_level = "medium"
            review_decision = "human_review_recommended"
        else:
            confidence_level = "low"
            review_decision = "human_review_required"

        prediction["confidence_level"] = confidence_level
        prediction["review_decision"] = review_decision

        reviewed_predictions.append(prediction)

    return reviewed_predictions

# %%
test_predictions_with_review = add_confidence_and_review(test_predictions)

test_predictions_with_review
# Out:
# [{'concept': 'hypertension',
#   'code_system': 'ICD-10-CM',
#   'code': 'I10',
#   'description': 'Essential hypertension',
#   'snomed_ct_candidate': 'Essential hypertension',
#   'clinicalbert_similarity': 0.841,
#   'confidence_level': 'high',
#   'review_decision': 'candidate_auto_approve_for_demo'},
#  {'concept': 'type_2_diabetes',
#   'code_system': 'ICD-10-CM',
#   'code': 'E11.9',
#   'description': 'Type 2 diabetes mellitus without complications',
#   'snomed_ct_candidate': 'Type 2 diabetes mellitus',
#   'clinicalbert_similarity': 0.84,
#   'confidence_level': 'high',
#   'review_decision': 'candidate_auto_approve_for_demo'},
#  {'concept': 'ekg_service',
#   'code_system': 'CPT',
#   'code': 'CPT candidate for electrocardiogram',
#   'description': 'Electrocardiogram service or interpretation candidate',
#   'snomed_ct_candidate': 'Electrocardiogram procedure',
#   'clinicalbert_similarity': 0.733,
#   'confidence_level': 'medium',
#   'review_decision': 'human_review_recommended'}]

# %% [markdown]
# Apply ClinicalBERT Code Prediction to All Notes
#
# Now we run ClinicalBERT candidate prediction on every clinical note.

# %%
df["clinicalbert_code_predictions"] = df["clean_text"].apply(
    lambda text: add_confidence_and_review(
        predict_codes_with_clinicalbert(text, top_n=3)
    )
)

df[["note_id", "clinicalbert_code_predictions"]]
# Out:
#    note_id                      clinicalbert_code_predictions
# 0        1  [{'concept': 'ekg_service', 'code_system': 'CP...
# 1        2  [{'concept': 'ekg_service', 'code_system': 'CP...
# 2        3  [{'concept': 'ekg_service', 'code_system': 'CP...

# %% [markdown]
# Print ClinicalBERT Predictions Clearly
#
# Now we print:
#
# candidate code
# description
# SNOMED CT candidate
# similarity score
# confidence level
# review decision

# %%
for i in range(len(df)):
    print("NOTE ID:", df.iloc[i]["note_id"])
    print("NOTE:", df.iloc[i]["clean_text"])
    print()

    print("CLINICALBERT CODE PREDICTIONS:")

    for prediction in df.iloc[i]["clinicalbert_code_predictions"]:
        print()
        print("Concept:", prediction["concept"])
        print("Code system:", prediction["code_system"])
        print("Candidate code:", prediction["code"])
        print("Description:", prediction["description"])
        print("SNOMED CT candidate:", prediction["snomed_ct_candidate"])
        print("ClinicalBERT similarity:", prediction["clinicalbert_similarity"])
        print("Confidence level:", prediction["confidence_level"])
        print("Review decision:", prediction["review_decision"])

    print("=" * 100)
# Out:
# NOTE ID: 1
# NOTE: Pt is a 58 y/o male with Type 2 Diabetes. Currently taking Metformin 1000mg BID. HbA1c today is 7.8%, previously 7.2% three months ago. Denies chest pain. Plan: continue Metformin and follow up in 3 months.
#
# CLINICALBERT CODE PREDICTIONS:
#
# Concept: ekg_service
# Code system: CPT
# Candidate code: CPT candidate for electrocardiogram
# Description: Electrocardiogram service or interpretation candidate
# SNOMED CT candidate: Electrocardiogram procedure
# ClinicalBERT similarity: 0.731
# Confidence level: medium
# Review decision: human_review_recommended
#
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# SNOMED CT candidate: Essential hypertension
# ClinicalBERT similarity: 0.71
# Confidence level: medium
# Review decision: human_review_recommended
#
# Concept: type_2_diabetes
# Code system: ICD-10-CM
# Candidate code: E11.9
# Description: Type 2 diabetes mellitus without complications
# SNOMED CT candidate: Type 2 diabetes mellitus
# ClinicalBERT similarity: 0.625
# Confidence level: low
# Review decision: human_review_required
# ====================================================================================================
# NOTE ID: 2
# NOTE: Patient has HTN treated with Lisinopril 20mg daily. BP today 145/92. Reports dizziness last week after standing. Plan: monitor BP at home and return in 2 weeks.
#
# CLINICALBERT CODE PREDICTIONS:
#
# Concept: ekg_service
# Code system: CPT
# Candidate code: CPT candidate for electrocardiogram
# Description: Electrocardiogram service or interpretation candidate
# SNOMED CT candidate: Electrocardiogram procedure
# ClinicalBERT similarity: 0.735
# Confidence level: medium
# Review decision: human_review_recommended
#
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# SNOMED CT candidate: Essential hypertension
# ClinicalBERT similarity: 0.71
# Confidence level: medium
# Review decision: human_review_recommended
#
# Concept: type_2_diabetes
# Code system: ICD-10-CM
# Candidate code: E11.9
# Description: Type 2 diabetes mellitus without complications
# SNOMED CT candidate: Type 2 diabetes mellitus
# ClinicalBERT similarity: 0.617
# Confidence level: low
# Review decision: human_review_required
# ====================================================================================================
# NOTE ID: 3
# NOTE: Patient presents to ED with chest pain and shortness of breath. EKG shows ST elevation. Aspirin 325mg given in ED. Cardiology consulted immediately.
#
# CLINICALBERT CODE PREDICTIONS:
#
# Concept: ekg_service
# Code system: CPT
# Candidate code: CPT candidate for electrocardiogram
# Description: Electrocardiogram service or interpretation candidate
# SNOMED CT candidate: Electrocardiogram procedure
# ClinicalBERT similarity: 0.744
# Confidence level: medium
# Review decision: human_review_recommended
#
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# SNOMED CT candidate: Essential hypertension
# ClinicalBERT similarity: 0.733
# Confidence level: medium
# Review decision: human_review_recommended
#
# Concept: abnormal_ekg
# Code system: ICD-10-CM
# Candidate code: R94.31
# Description: Abnormal electrocardiogram
# SNOMED CT candidate: Abnormal electrocardiogram
# ClinicalBERT similarity: 0.663
# Confidence level: medium
# Review decision: human_review_recommended
# ====================================================================================================

# %% [markdown]
# WE can Now Combine Rule-Based Mapping + ClinicalBERT Prediction
#
# Your earlier notebook already had rule-based mapping.
#
# Now we combine:

# %% [markdown]
# Rule-based candidate codes
# +
# ClinicalBERT candidate codes
# +
# Evidence validation
# +
# Human review decision

# %% [markdown]
# Combine Rule-Based Codes and ClinicalBERT Codes
#
# Rule-based coding uses exact patterns.
#
# ClinicalBERT coding uses meaning similarity.
#
# Together they are stronger than either alone.
#
# Rule-based system:
#
# Good when wording is exact.
#
# ClinicalBERT system:
#
# Helpful when wording varies.

# %%
def combine_rule_and_clinicalbert_outputs(rule_codes, clinicalbert_codes):
    combined = []

    for rule_code in rule_codes:
        combined.append({
            "source": "rule_based_mapping",
            "concept": rule_code["concept"],
            "code_system": rule_code["code_system"],
            "code": rule_code["code"],
            "description": rule_code["description"],
            "evidence": rule_code["evidence"],
            "confidence_level": "rule_match",
            "review_decision": "human_review_recommended",
            "note": "Rule-based candidate with evidence."
        })

    for bert_code in clinicalbert_codes:
        combined.append({
            "source": "clinicalbert_similarity",
            "concept": bert_code["concept"],
            "code_system": bert_code["code_system"],
            "code": bert_code["code"],
            "description": bert_code["description"],
            "evidence": "ClinicalBERT similarity match, evidence must be checked manually.",
            "confidence_level": bert_code["confidence_level"],
            "review_decision": bert_code["review_decision"],
            "note": "ClinicalBERT semantic candidate. Needs evidence review."
        })

    return combined

# %%
df["combined_code_candidates"] = df.apply(
    lambda row: combine_rule_and_clinicalbert_outputs(
        row["validated_codes"],
        row["clinicalbert_code_predictions"]
    ),
    axis=1
)

df[["note_id", "combined_code_candidates"]]
# Out:
#    note_id                           combined_code_candidates
# 0        1  [{'source': 'rule_based_mapping', 'concept': '...
# 1        2  [{'source': 'rule_based_mapping', 'concept': '...
# 2        3  [{'source': 'rule_based_mapping', 'concept': '...

# %% [markdown]
# Print Final Combined Output
#
# This final output shows:
#
# Rule-based code suggestions
# ClinicalBERT code suggestions
# Confidence level
# Human review decision

# %%
for i in range(len(df)):
    print("NOTE ID:", df.iloc[i]["note_id"])
    print("NOTE:", df.iloc[i]["clean_text"])
    print()

    print("FINAL COMBINED CODE CANDIDATES:")

    for candidate in df.iloc[i]["combined_code_candidates"]:
        print()
        print("Source:", candidate["source"])
        print("Concept:", candidate["concept"])
        print("Code system:", candidate["code_system"])
        print("Candidate code:", candidate["code"])
        print("Description:", candidate["description"])
        print("Evidence:", candidate["evidence"])
        print("Confidence:", candidate["confidence_level"])
        print("Review decision:", candidate["review_decision"])
        print("Note:", candidate["note"])

    print("=" * 100)
# Out:
# NOTE ID: 1
# NOTE: Pt is a 58 y/o male with Type 2 Diabetes. Currently taking Metformin 1000mg BID. HbA1c today is 7.8%, previously 7.2% three months ago. Denies chest pain. Plan: continue Metformin and follow up in 3 months.
#
# FINAL COMBINED CODE CANDIDATES:
#
# Source: rule_based_mapping
# Concept: type_2_diabetes
# Code system: ICD-10-CM
# Candidate code: E11.9
# Description: Type 2 diabetes mellitus without complications
# Evidence: Type 2 Diabetes
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: rule_based_mapping
# Concept: follow_up_planned
# Code system: Workflow
# Candidate code: FOLLOW_UP
# Description: Follow-up planned
# Evidence: follow up
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: clinicalbert_similarity
# Concept: ekg_service
# Code system: CPT
# Candidate code: CPT candidate for electrocardiogram
# Description: Electrocardiogram service or interpretation candidate
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
#
# Source: clinicalbert_similarity
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
#
# Source: clinicalbert_similarity
# Concept: type_2_diabetes
# Code system: ICD-10-CM
# Candidate code: E11.9
# Description: Type 2 diabetes mellitus without complications
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: low
# Review decision: human_review_required
# Note: ClinicalBERT semantic candidate. Needs evidence review.
# ====================================================================================================
# NOTE ID: 2
# NOTE: Patient has HTN treated with Lisinopril 20mg daily. BP today 145/92. Reports dizziness last week after standing. Plan: monitor BP at home and return in 2 weeks.
#
# FINAL COMBINED CODE CANDIDATES:
#
# Source: rule_based_mapping
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# Evidence: hypertension
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: rule_based_mapping
# Concept: follow_up_planned
# Code system: Workflow
# Candidate code: FOLLOW_UP
# Description: Follow-up planned
# Evidence: return in
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: clinicalbert_similarity
# Concept: ekg_service
# Code system: CPT
# Candidate code: CPT candidate for electrocardiogram
# Description: Electrocardiogram service or interpretation candidate
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
#
# Source: clinicalbert_similarity
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
#
# Source: clinicalbert_similarity
# Concept: type_2_diabetes
# Code system: ICD-10-CM
# Candidate code: E11.9
# Description: Type 2 diabetes mellitus without complications
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: low
# Review decision: human_review_required
# Note: ClinicalBERT semantic candidate. Needs evidence review.
# ====================================================================================================
# NOTE ID: 3
# NOTE: Patient presents to ED with chest pain and shortness of breath. EKG shows ST elevation. Aspirin 325mg given in ED. Cardiology consulted immediately.
#
# FINAL COMBINED CODE CANDIDATES:
#
# Source: rule_based_mapping
# Concept: chest_pain
# Code system: ICD-10-CM
# Candidate code: R07.9
# Description: Chest pain, unspecified
# Evidence: chest pain
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: rule_based_mapping
# Concept: shortness_of_breath
# Code system: ICD-10-CM
# Candidate code: R06.02
# Description: Shortness of breath
# Evidence: shortness of breath
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: rule_based_mapping
# Concept: abnormal_ekg
# Code system: ICD-10-CM
# Candidate code: R94.31
# Description: Abnormal electrocardiogram
# Evidence: ST elevation
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: rule_based_mapping
# Concept: ekg_performed_or_reviewed
# Code system: CPT
# Candidate code: EKG CPT candidate
# Description: Electrocardiogram service candidate
# Evidence: electrocardiogram
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: rule_based_mapping
# Concept: medication_given
# Code system: Workflow
# Candidate code: MED_ADMIN_REVIEW
# Description: Medication administration mentioned
# Evidence: Aspirin 325mg given
# Confidence: rule_match
# Review decision: human_review_recommended
# Note: Rule-based candidate with evidence.
#
# Source: clinicalbert_similarity
# Concept: ekg_service
# Code system: CPT
# Candidate code: CPT candidate for electrocardiogram
# Description: Electrocardiogram service or interpretation candidate
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
#
# Source: clinicalbert_similarity
# Concept: hypertension
# Code system: ICD-10-CM
# Candidate code: I10
# Description: Essential hypertension
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
#
# Source: clinicalbert_similarity
# Concept: abnormal_ekg
# Code system: ICD-10-CM
# Candidate code: R94.31
# Description: Abnormal electrocardiogram
# Evidence: ClinicalBERT similarity match, evidence must be checked manually.
# Confidence: medium
# Review decision: human_review_recommended
# Note: ClinicalBERT semantic candidate. Needs evidence review.
# ====================================================================================================

# %% [markdown]
# Now the pipeline includes ClinicalBERT.
#
# The updated workflow is:
#
# Clinical Note
# ↓
# Tokenization + Normalization
# ↓
# NER, find entities
# ↓
# Context + Time understanding
# ↓
# Rule-based concept classification
# ↓
# ClinicalBERT semantic code prediction
# ↓
# Map to ICD / CPT / SNOMED CT candidates
# ↓
# Confidence scoring
# ↓
# Human review decision
# ↓
# Final coded output
#
# ClinicalBERT helps with clinical language understanding.
#
# Rule-based mapping helps with clear evidence.
#
# Vocabulary mapping standardizes language.
#
# Confidence scoring helps decide what needs human review.
